# %%
# https://docs.microsoft.com/en-us/python/api/overview/azure/ml/install?view=azure-ml-py

# %%
from azureml.core import Workspace
from azureml.core.compute import ComputeTarget
from azureml.core.experiment import Experiment
from azureml.core import Environment
from azureml.core import ScriptRunConfig

# %%
ws = Workspace.from_config()

# %%
experiment_name = "iris_experiment"
compute_target = ComputeTarget(workspace=ws, name="vbci-ds3")
sklearn_env = Environment.from_conda_specification(name="iris_sklearn_env", file_path="conda_dependencies.yml")

src = ScriptRunConfig(source_directory = ".",
                      script = "train_iris.py",
                      arguments = ['--kernel', 'linear', '--penalty', 1.0],
#                       compute_target = compute_target,
                      environment = sklearn_env)

run = Experiment(ws, "train_iris").submit(src)

# run.wait_for_completion(show_output=True)
compute_target.stop(wait_for_completion=True, show_output=True)
# Out:
# RunId: train_iris_1642099679_164c99a4
# Web View: https://ml.azure.com/runs/train_iris_1642099679_164c99a4?wsid=/subscriptions/7133a1fb-b8c7-4354-a2a0-7cae8cb9ad82/resourcegroups/rg-uksouth-d-hac-analytics/workspaces/ml-workspace-op-d-hac-analytics&tid=47804908-ccd2-4fc1-8075-3f48df960aad
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
#
# Streaming azureml-logs/55_azureml-execution-tvmps_c2d7b0504f679647a8387cfd90521fe6cebe79400b0adb8b5286fdf2d493507d_d.txt
# ========================================================================================================================
#
# 2022-01-13T18:53:20Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ml-workspace-op-d-hac-analytics/azureml/train_iris_1642099679_164c99a4/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ml-workspace-op-d-hac-analytics/azureml/train_iris_1642099679_164c99a4/caches/workspaceblobstore -o ro --file-cache-timeout-in-seconds=1000000 --cache-size-mb=10782 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ml-workspace-op-d-hac-analytics/azureml/train_iris_1642099679_164c99a4/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2022-01-13T18:53:20Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ml-workspace-op-d-hac-analytics/azureml/train_iris_1642099679_164c99a4/mounts/workspaceblobstore -- stdout/stderr:
# 2022-01-13T18:53:21Z The vmsize standard_ds3_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2022-01-13T18:53:21Z Starting output-watcher...
# 2022-01-13T18:53:21Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2022-01-13T18:53:21Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2022-01-13T18:53:21Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_61f69e7cef47619c22438563f158fa30
# 284055322776: Pulling fs layer
# 56c2761c3a56: Pulling fs layer
# e7dff8330ff9: Pulling fs layer
# c782690959f6: Pulling fs layer
# 722c34119f7e: Pulling fs layer
# 2df507734fe8: Pulling fs layer
# 858f3d745b66: Pulling fs layer
# 7c1ed34d7266: Pulling fs layer
# 1ef5f8a4fad5: Pulling fs layer
# 97244f845db6: Pulling fs layer
# 7a405577b268: Pulling fs layer
# acddb8138359: Pulling fs layer
# 7d860bcf046c: Pulling fs layer
# 30b518b45de2: Pulling fs layer
# c24c06a4f0ae: Pulling fs layer
# dad724ccd23d: Pulling fs layer
# 1b1b7e7e01a2: Pulling fs layer
# 48400b00271b: Pulling fs layer
# 52c30eacdeb7: Pulling fs layer
# 2df507734fe8: Waiting
# 858f3d745b66: Waiting
# 7c1ed34d7266: Waiting
# 1ef5f8a4fad5: Waiting
# 97244f845db6: Waiting
# 7a405577b268: Waiting
# acddb8138359: Waiting
# 7d860bcf046c: Waiting
# 30b518b45de2: Waiting
# c24c06a4f0ae: Waiting
# dad724ccd23d: Waiting
# 1b1b7e7e01a2: Waiting
# 48400b00271b: Waiting
# 52c30eacdeb7: Waiting
# c782690959f6: Waiting
# 722c34119f7e: Waiting
# e7dff8330ff9: Verifying Checksum
# e7dff8330ff9: Download complete
# 284055322776: Verifying Checksum
# 284055322776: Download complete
# c782690959f6: Verifying Checksum
# c782690959f6: Download complete
# 2df507734fe8: Verifying Checksum
# 2df507734fe8: Download complete
# 56c2761c3a56: Verifying Checksum
# 56c2761c3a56: Download complete
# 7c1ed34d7266: Verifying Checksum
# 7c1ed34d7266: Download complete
# 1ef5f8a4fad5: Verifying Checksum
# 1ef5f8a4fad5: Download complete
# 97244f845db6: Verifying Checksum
# 97244f845db6: Download complete
# 284055322776: Pull complete
# 858f3d745b66: Verifying Checksum
# 858f3d745b66: Download complete
# 722c34119f7e: Download complete
# 7a405577b268: Verifying Checksum
# 7a405577b268: Download complete
# acddb8138359: Verifying Checksum
# acddb8138359: Download complete
# 7d860bcf046c: Verifying Checksum
# 7d860bcf046c: Download complete
# c24c06a4f0ae: Verifying Checksum
# c24c06a4f0ae: Download complete
# dad724ccd23d: Download complete
# 48400b00271b: Verifying Checksum
# 48400b00271b: Download complete
# 1b1b7e7e01a2: Verifying Checksum
# 1b1b7e7e01a2: Download complete
# 52c30eacdeb7: Verifying Checksum
# 52c30eacdeb7: Download complete
# 30b518b45de2: Verifying Checksum
# 30b518b45de2: Download complete
# 56c2761c3a56: Pull complete
# e7dff8330ff9: Pull complete
# c782690959f6: Pull complete
# 722c34119f7e: Pull complete
# 2df507734fe8: Pull complete
# 858f3d745b66: Pull complete
# 7c1ed34d7266: Pull complete
# 1ef5f8a4fad5: Pull complete
# 97244f845db6: Pull complete
# 7a405577b268: Pull complete
# acddb8138359: Pull complete
# 7d860bcf046c: Pull complete
#
# Streaming azureml-logs/75_job_post-tvmps_c2d7b0504f679647a8387cfd90521fe6cebe79400b0adb8b5286fdf2d493507d_d.txt
# ===============================================================================================================
#
# [2022-01-13T18:54:23.558067] Entering job release
# [2022-01-13T18:54:24.630717] Starting job release
# [2022-01-13T18:54:24.631293] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 144
# [2022-01-13T18:54:24.632146] job release stage : upload_datastore starting...
# [2022-01-13T18:54:24.632551] job release stage : start importing azureml.history._tracking in run_history_release.
# [2022-01-13T18:54:24.636494] job release stage : execute_job_release starting...
# [2022-01-13T18:54:24.642781] job release stage : copy_batchai_cached_logs starting...
# [2022-01-13T18:54:24.642822] job release stage : copy_batchai_cached_logs completed...
# [2022-01-13T18:54:24.646701] Entering context manager injector.
# [2022-01-13T18:54:24.648466] job release stage : upload_datastore completed...
# [2022-01-13T18:54:24.730084] job release stage : send_run_telemetry starting...
# [2022-01-13T18:54:24.752088] get vm size and vm region successfully.
# [2022-01-13T18:54:24.764057] get compute meta data successfully.
# [2022-01-13T18:54:24.908154] job release stage : execute_job_release completed...
# [2022-01-13T18:54:25.047044] post artifact meta request successfully.
# [2022-01-13T18:54:25.124280] upload compute record artifact successfully.
# [2022-01-13T18:54:25.124376] job release stage : send_run_telemetry completed...
# [2022-01-13T18:54:25.124609] Job release is complete
#
# Execution Summary
# =================
# RunId: train_iris_1642099679_164c99a4
# Web View: https://ml.azure.com/runs/train_iris_1642099679_164c99a4?wsid=/subscriptions/7133a1fb-b8c7-4354-a2a0-7cae8cb9ad82/resourcegroups/rg-uksouth-d-hac-analytics/workspaces/ml-workspace-op-d-hac-analytics&tid=47804908-ccd2-4fc1-8075-3f48df960aad
# {'runId': 'train_iris_1642099679_164c99a4',
#  'target': 'vbci-ds3',
#  'status': 'Completed',
#  'startTimeUtc': '2022-01-13T18:53:19.858159Z',
#  'endTimeUtc': '2022-01-13T18:54:34.778299Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'fe7a36a5-3337-4f2f-b8fa-136f192af0cb',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train_iris.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--kernel', 'linear', '--penalty', '1'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'vbci-ds3',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'datacaches': [],
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'instanceTypes': [],
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'iris_sklearn_env',
#    'version': 'Autosave_2022-01-13T18:42:24Z_59fbeae0',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'dependencies': ['python=3.6.2',
#       'scikit-learn',
#       'numpy',
#       'pip',
#       {'pip': ['azureml-defaults']}],
#      'name': 'azureml_c0bbaf957c9060d039962f91b277b1f2'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20211124.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': 'D2',
#    'imageVersion': 'pytorch-1.7.0',
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None,
#    'sshPublicKeys': None,
#    'enableAzmlInt': True,
#    'priority': 'Medium',
#    'slaTier': 'Standard',
#    'userAlias': None},
#   'kubernetesCompute': {'instanceType': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {},
#   'parameters': []},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://saproduksouthdopmlws.blob.core.windows.net/azureml/ExperimentRun/dcid.train_iris_1642099679_164c99a4/azureml-logs/20_image_build_log.txt?sv=2019-07-07&sr=b&sig=3x0DLtB40y6dvAoJQrO3XRm%2Fr1TaFH2o8aaKsw5lAgY%3D&skoid=d8d57065-2505-4cde-832b-b80a3d423746&sktid=47804908-ccd2-4fc1-8075-3f48df960aad&skt=2022-01-13T18%3A23%3A17Z&ske=2022-01-15T02%3A33%3A17Z&sks=b&skv=2019-07-07&st=2022-01-13T18%3A44%3A55Z&se=2022-01-14T02%3A54%3A55Z&sp=r',
